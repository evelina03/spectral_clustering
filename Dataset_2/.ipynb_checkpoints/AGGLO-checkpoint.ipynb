# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering 
import seaborn as sns
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("Flu_Classification.csv")
df.head()
# Out:
#     Age  Temperature Sex Diarrhea    Fever Coughing ShortnessOfBreath  \
# 0  67.0        38.11   F  unknown      Yes      Yes           unknown
# 1  29.0         0.00   M  unknown  unknown  unknown           unknown
# 2  22.0         0.00   F  unknown  unknown  unknown           unknown
# 3  20.0        36.56   F  unknown      Yes      Yes           unknown
# 4  21.0         0.00   M  unknown  unknown  unknown           unknown
#
#   SoreThroat NauseaVomitting  Fatigue   Cancer Diagnosis
# 0         No         unknown       No  unknown      H1N1
# 1    unknown         unknown  unknown  unknown      H1N1
# 2    unknown         unknown  unknown  unknown      H1N1
# 3         No         unknown      Yes  unknown      H1N1
# 4    unknown         unknown  unknown  unknown      H1N1

# %%
# Converting string categorical variables into numeric categorical variables

def convert(df, n, k) :
    for col in df.iloc[:,n:k].columns:
        df[col] = df[col].astype('category').cat.codes
        
    return df

# %%
def dendogram (df, method) :
    
    dendrogram = sch.dendrogram(sch.linkage(df, method  = method))
    plt.title('Dendrogram')
    plt.xlabel('Patients')
    plt.ylabel('Euclidean distances')
    plot = plt.show()
    
    return plot

# %%
def agglomerative_clustering (df, n, affinity, linkage):
    
    hc = AgglomerativeClustering(n_clusters = n, affinity = affinity, linkage = linkage)

    df["cluster"] = hc.fit_predict(df)

    pca = PCA(2)

    df['PC1'] = pca.fit_transform(df)[:,0]
    df['PC2'] = pca.fit_transform(df)[:,1]


    plot = sns.scatterplot(data=df,x="PC1",y="PC2",hue=df['cluster'])
    
    return df, plot

# %%
df = convert(df, 2,12)
df_cluster = df.iloc[:,0:11]

dendogram(df_cluster,"ward")

df_cluster, plot = agglomerative_clustering(df_cluster, 3, 'euclidean', 'ward')

df_cluster.head()
# Out:
#     Age  Temperature  Sex  Diarrhea  Fever  Coughing  ShortnessOfBreath  \
# 0  67.0        38.11    0         2      1         1                  2
# 1  29.0         0.00    1         2      2         2                  2
# 2  22.0         0.00    0         2      2         2                  2
# 3  20.0        36.56    0         2      1         1                  2
# 4  21.0         0.00    1         2      2         2                  2
#
#    SoreThroat  NauseaVomitting  Fatigue  Cancer  cluster        PC1        PC2
# 0           0                2        0       1        0  46.088456  -6.433248
# 1           2                2        2       1        1  -2.800189  16.192415
# 2           2                2        2       1        1  -9.362307  13.770060
# 3           0                2        1       1        0   1.468368 -21.259705
# 4           2                2        2       1        1 -10.302711  13.418542
